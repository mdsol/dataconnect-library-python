# %%
from dataconnect import DataConnectClient

with DataConnectClient.connect(
    host="enodia-gateway-sandbox.platform.imedidata.net",
    port=443,
    token="eyJhbGciOiJSUzI1NiIsInR5cCI6IkpXVCJ9..o0H_xM-_COmqa33HBbDgJ-A7E1u6PeNv5giIPy44QIs9IthbJJyecNwVanTogWiAZMqnq6pXVu41GnyjYEt-d8Oh_HOUibH0xu-8KEnw-8ZcStuCyzmj4qLJjJmm4YHE05W0KQNG2BlZ9f2073y_8oxfrkytSxAtJZlJEVOUZBWI9VA9S1eUMGSGTdAv7Io4lnM66kNseCaJzzuFjIb3fgbrIS5tDq7kgR34-jDGQXULHUF5oziS9w5JbSURAppKoIeTvrht4biSXJA79J0K8qq7f271zdFeaCf7BYx9-MlrOuR0YYTBO2puqPuNLWYtQqofu1jd3LkiDwJIRkS2DQ",
) as client:
    print(client)

# %%
studies = client.get_studies()
print(studies)
# Out:
# ---------------------------------------------------------------------------
# ArrowInvalid                              Traceback (most recent call last)
# File ~/repos/dataconnect-library-python/dataconnect/transport/arrow_flight/transport.py:89, in ArrowFlightTransport.list_resources(self, request)
#      88     raw_flights = self._client.list_flights(criteria, self._options())
# ---> 89     return [_to_resource_info(f) for f in raw_flights]
#      91 except flight.FlightUnauthenticatedError as ex:
#
# File pyarrow/_flight.pyx:1649, in list_flights()
# -> 1649 'Could not get source, probably due dynamically evaluated source code.'
#
# File pyarrow/_flight.pyx:1653, in pyarrow._flight.FlightClient.list_flights()
# -> 1653 'Could not get source, probably due dynamically evaluated source code.'
#
# File pyarrow/_flight.pyx:78, in pyarrow._flight.check_flight_status()
# ---> 78 'Could not get source, probably due dynamically evaluated source code.'
#
# ...
